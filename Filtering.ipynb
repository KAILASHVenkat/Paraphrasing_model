# %% [markdown]
# <a href="https://colab.research.google.com/github/KAILASHVenkat/Paraphrasing_model/blob/main/Filtering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
url = "https://github.com/SoumyaSJha/TextToneTune/raw/main/dataset/t3_data%20copy.csv"
df = pd.read_csv(url)
df
# Out:
#                                               input_text  \
# 0      admiration to approval: The entire relay throu...
# 1      excitement to surprise: People who saw the tor...
# 2      excitement to admiration: At the 23rd Japan Go...
# 3      disappointment to disapproval: Usually we lost...
# 4      optimism to approval: Reviews were positive, t...
# ...                                                  ...
# 13958  confusion to disappointment: How do I unsubscr...
# 13959  confusion to curiosity: I start learning progr...
# 13960          confusion to curiosity: Why MBA after BE?
# 13961  admiration to curiosity: Which is the Good hot...
# 13962  curiosity to annoyance: Why is Manaphy childis...
#
#                                              target_text
# 0      The entire relay through Mainland China was la...
# 1      People who saw the torch were surprised and ch...
# 2      At the 23rd Japan Gold Disc Awards, Madonna wa...
# ...

# %%
df[['e1', 'e2']] = df['input_text'].str.split(expand=True)[[0, 2]]
df['e2'] = df['e2'].str.strip(':')
df
# Out:
#                                               input_text  \
# 0      admiration to approval: The entire relay throu...
# 1      excitement to surprise: People who saw the tor...
# 2      excitement to admiration: At the 23rd Japan Go...
# 3      disappointment to disapproval: Usually we lost...
# 4      optimism to approval: Reviews were positive, t...
# ...                                                  ...
# 13958  confusion to disappointment: How do I unsubscr...
# 13959  confusion to curiosity: I start learning progr...
# 13960          confusion to curiosity: Why MBA after BE?
# 13961  admiration to curiosity: Which is the Good hot...
# 13962  curiosity to annoyance: Why is Manaphy childis...
#
#                                              target_text              e1  \
# 0      The entire relay through Mainland China was la...      admiration
# 1      People who saw the torch were surprised and ch...      excitement
# ...

# %%
unique_e1_values = df['e1'].unique()
unique_e2_values = df['e2'].unique()

print("Unique values in 'e1' column:", unique_e1_values)
print("Unique values in 'e2' column:", unique_e2_values)
# Out:
# Unique values in 'e1' column: ['admiration' 'excitement' 'disappointment' 'optimism' 'love' 'approval'
#  'gratitude' 'sadness' 'confusion' 'realization' 'surprise' 'pride' 'joy'
#  'annoyance' 'fear' 'disgust' 'caring' 'amusement' 'anger' 'remorse'
#  'curiosity' 'nervousness' 'desire' 'embarrassment' 'relief']
# Unique values in 'e2' column: ['approval' 'surprise' 'admiration' 'disapproval' 'disappointment'
#  'confusion' 'embarrassment' 'sadness' 'realization' 'caring' 'remorse'
#  'joy' 'nervousness' 'annoyance' 'curiosity' 'desire' 'fear' 'love'
#  'gratitude' 'optimism' 'relief' 'anger' 'disgust' 'excitement']

# %%
high_negative_emotions = ['anger', 'disgust', 'grief', 'fear', 'sadness']
low_negative_emotions = ['nervousness', 'annoyance', 'disappointment', 'embarrassment', 'remorse', 'disapproval']
neutral_emotions = ['confusion', 'curiosity', 'realization', 'surprise']
low_positive_emotions = ['approval', 'caring', 'desire', 'relief']
high_positive_emotions = ['amusement', 'excitement', 'pride', 'optimism', 'gratitude', 'joy', 'admiration', 'love']

# Applying rules to filter DataFrame
filtered_df = df[
    (df['e1'].isin(high_positive_emotions) & ((df['e2'].isin(low_positive_emotions)) | (df['e2'].isin(neutral_emotions)))) |
    ((df['e1'].isin(low_positive_emotions) | df['e1'].isin(neutral_emotions)) & (df['e2'].isin(neutral_emotions))) |
    ((df['e1'].isin(low_negative_emotions)) & (df['e2'].isin(neutral_emotions))) |
    (df['e1'].isin(high_negative_emotions) & ((df['e2'].isin(low_negative_emotions)) | df['e2'].isin(neutral_emotions)))
]

# Displaying the filtered DataFrame
df = filtered_df.drop(['e1', 'e2'], axis=1)


df
# Out:
#                                               input_text  \
# 0      admiration to approval: The entire relay throu...
# 1      excitement to surprise: People who saw the tor...
# 4      optimism to approval: Reviews were positive, t...
# 5      admiration to approval: The interest in the Cl...
# 6      love to approval: It is a tragic story of undy...
# ...                                                  ...
# 13955  confusion to curiosity: How do I reset my Gmai...
# 13956       confusion to curiosity: Why does 0! Equal 1?
# 13959  confusion to curiosity: I start learning progr...
# 13960          confusion to curiosity: Why MBA after BE?
# 13961  admiration to curiosity: Which is the Good hot...
#
#                                              target_text
# 0      The entire relay through Mainland China was la...
# 1      People who saw the torch were surprised and ch...
# 4      Reviews were positive, though slightly more mi...
# ...

# %%
df.to_csv('filtered_data.csv', index=False)

# %%
from google.colab import files
files.download('filtered_data.csv')
